# %%
from czi_to_zarr import czi_to_omezarr_folder, nd2_to_zarr, organize_czi_multipos_folder

# %%
organize_czi_multipos_folder(r'P:\Kai\2021-08-17_KSB014_1D_HKRad21AID_4x10pos_aux_elyratracing\fish')

# %%
input_folders = [r'P:\Kai\2021-08-17_KSB014_1D_HKRad21AID_4x10pos_aux_elyratracing\dapi',
                r'P:\Kai\2021-08-17_KSB014_1D_HKRad21AID_4x10pos_aux_elyratracing\fish']
out_path = r'P:\Kai\2021-08-17_KSB014_1D_HKRad21AID_4x10pos_aux_elyratracing\zarr_images_fish'

czi_to_omezarr_folder(input_folders, out_path, flip_ch_idx=(0,), continue_from = None)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Found files of shape: (20, 2, 61, 1280, 1280)
# 31 0
# 31 1
# 31 2
# 31 3
# 31 4
# 31 5
# 31 6
# 31 7
# 31 8
# 31 9
# 31 10
# 31 11
# 31 12
# 31 13
# 31 14
# 31 15
# 31 16
# 31 17
# 31 18
# 31 19
# 31 20
# 31 21
# 31 22
# 31 23
# 31 24
# 31 25
# 31 26
# 31 27
# 31 28
# 31 29
# 31 30
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.

# %%
input_path = r"P:\Kai\2021-08-17_MT001_NikonTiE2_HKWT_nosync_beads_Tel647"
out_path = r"P:\Kai\2021-08-17_MT001_NikonTiE2_HKWT_nosync_beads_Tel647\zarr_test"
nd2_to_zarr(input_path, out_path)
# Out:
# Found files of shape: (2, 2, 46, 2304, 2304)
#  67%|██████▋   | 2/3 [02:44<01:22, 82.48s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-638ffb1a03d6> in <module>
#       1 input_path = r"P:\Kai\2021-08-17_MT001_NikonTiE2_HKWT_nosync_beads_Tel647"
#       2 out_path = r"P:\Kai\2021-08-17_MT001_NikonTiE2_HKWT_nosync_beads_Tel647\zarr_test"
# ----> 3 nd2_to_zarr(input_path, out_path)
#
# c:\Git\looptrace_dev\preprocess\czi_to_zarr.py in nd2_to_zarr(folder_path, out_path)
#     147                 images.bundle_axes = 'czyx'
#     148                 images.iter_axes = 'v'
# --> 149                 multiscale_level[j] = images[i]
#
# ~\miniconda3\envs\looptrace\lib\site-packages\slicerator\__init__.py in __getitem__(self, i)
#     186                 indices, new_length = key_to_indices(i, len(self))
#     187                 if new_length is None:
# ...

# %%
from nd2reader import ND2Reader
import json
import datetime
with ND2Reader(r"P:\Kai\2021-08-17_MT001_NikonTiE2_HKWT_nosync_beads_Tel647\21-08-17_MT001_Ibidi1B_stack019.nd2") as images:
    sample_shape = images.sizes
    X = sample_shape['x']
    Y = sample_shape['y']
    Z = sample_shape['z']
    C = sample_shape['c']
    P = sample_shape['v']
    s = (C, Z, Y, X)
    meta = images.metadata
    def datetime_to_str(o):
        if isinstance(o, datetime.datetime):
            return o.__str__()
    print(type(json.loads(json.dumps(meta, default=datetime_to_str))))
# Out:
# <class 'dict'>
